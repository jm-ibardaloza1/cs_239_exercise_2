# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# location = /content/drive/MyDrive/CS\ 239/Backups/exercise_1/code/
# !nvcc -arch=sm_75 -o /content/drive/MyDrive/CS\ 239/Backups/exercise_2/code/matrix_multiplication /content/drive/MyDrive/CS\ 239/Backups/exercise_2/code/matrix_multiplication.cu

# %%
# !/content/drive/MyDrive/CS\ 239/Backups/exercise_2/code/matrix_multiplication --matrix_1_height 5000 --matrix_1_width 2000 --matrix_2_width 3000
# Out:
# Matrix 1 height: 5000
# Matrix 1 width: 2000
# Matrix 2 height: 2000
# Matrix 1 height: 3000
# Found 1 CUDA capable device(s).
# Device Name: Tesla T4
# Device UUID: 2c1c9d552438661dc70c778b177ea95f
# LUID: 00000000000000000000000000000000
# LUID Device Node Mask: 0
# Total Global Memory: 15828320256 bytes
# Shared Memory per Block: 49152 bytes
# Registers per Block: 65536
# Warp Size: 32
# Memory Pitch: 2147483647 bytes
# Max Threads per Block: 1024
# Max Threads Dim:  1024 x 1024 x 64
# Max Grid Size: 2147483647 x 65535 x 65535
# Total Constant Memory: 65536 bytes
# Major: 7
# Minor: 5
# Compute Capability: 7.5
# Texture Alignment: 512
# Texture Pitch: 32
# MultiProcessor Count: 40
# Integrated: 0
# Can Map Host Memory: 1
# Max Texture 1D: 131072
# Max Texture 1D Mipmap: 32768
# Max Texture 2D:  131072 x 65536
# Max Texture 2D Mipmap:  32768 x 32768
# Max Texture 2D Linear:  131072 x 65000 x 2097120
# Max Texture 2D Gather:  32768 x 32768
# Max Texture 3D:  16384 x 16384 x 16384
# ...
